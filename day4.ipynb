# %% [markdown]
# <a href="https://colab.research.google.com/github/Atul210704/atulsharma/blob/main/day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("day4")
# Out:
# day4
