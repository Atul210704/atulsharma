# %% [markdown]
# <a href="https://colab.research.google.com/github/Atul210704/atulsharma/blob/main/day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("rajendra")
# Out:
# rajendra

# %%
# variable
a = "hello"
print(a)
print(id(a))

b = "hello"
print(b)
print(id(b))
# Out:
# hello
# 133236142436688
# hello
# 133236142436688
